# %% [markdown]
# Regularization methods such as L1 and L2 are techniques used in machine learning to prevent overfitting and improve the generalization of models. Here’s a step-by-step guide on how to apply these methods:
#
# ### L1 Regularization (Lasso)
#
# L1 regularization adds a penalty equal to the absolute value of the magnitude of coefficients. It can lead to sparse models where some feature weights are exactly zero. This means L1 can be used for feature selection.
#
# **Steps to apply L1 Regularization:**
#
# 1. **Define your model**: Choose a machine learning algorithm that supports regularization, such as linear regression, logistic regression, or neural networks.
#
# 2. **Add the L1 term to the cost function**: The regularized cost function for L1 regularization is:
#
#    \[
#    J(\theta) = \frac{1}{m} \sum_{i=1}^{m} \mathcal{L}(h_\theta(x^{(i)}), y^{(i)}) + \lambda \sum_{j=1}^{n} |\theta_j|
#    \]
#
#    where:
#    - \( J(\theta) \) is the cost function
#    - \( m \) is the number of training examples
#    - \( \mathcal{L} \) is the loss function (e.g., mean squared error for regression)
#    - \( h_\theta(x) \) is the hypothesis
#    - \( y \) is the actual output
#    - \( \theta \) are the model parameters
#    - \( \lambda \) is the regularization parameter that controls the strength of the penalty
#
# 3. **Use libraries**: In practice, use machine learning libraries like Scikit-learn in Python which provide built-in support for L1 regularization.
#
#    ```python
#    from sklearn.linear_model import Lasso
#
#    # Instantiate a Lasso regressor with a regularization parameter alpha
#    lasso = Lasso(alpha=1.0)
#    lasso.fit(X_train, y_train)
#
#    # Predict
#    y_pred = lasso.predict(X_test)
#    ```
#
# ### L2 Regularization (Ridge)
#
# L2 regularization adds a penalty equal to the squared magnitude of coefficients. It discourages large weights by adding the squared values of the coefficients to the loss function.
#
# **Steps to apply L2 Regularization:**
#
# 1. **Define your model**: Choose an appropriate machine learning algorithm.
#
# 2. **Add the L2 term to the cost function**: The regularized cost function for L2 regularization is:
#
#    \[
#    J(\theta) = \frac{1}{m} \sum_{i=1}^{m} \mathcal{L}(h_\theta(x^{(i)}), y^{(i)}) + \lambda \sum_{j=1}^{n} \theta_j^2
#    \]
#
#    where the terms are the same as defined above, except the penalty term now includes the squared values of the coefficients.
#
# 3. **Use libraries**: Similarly, you can use libraries like Scikit-learn to implement L2 regularization.
#
#    ```python
#    from sklearn.linear_model import Ridge
#
#    # Instantiate a Ridge regressor with a regularization parameter alpha
#    ridge = Ridge(alpha=1.0)
#    ridge.fit(X_train, y_train)
#
#    # Predict
#    y_pred = ridge.predict(X_test)
#    ```
#
# ### Combining L1 and L2 Regularization (Elastic Net)
#
# Elastic Net combines both L1 and L2 regularization. This can sometimes yield better results by balancing the benefits of both methods.
#
# **Steps to apply Elastic Net Regularization:**
#
# 1. **Define your model**: Choose an appropriate algorithm that supports elastic net.
#
# 2. **Add the combined L1 and L2 terms to the cost function**: The regularized cost function is:
#
#    \[
#    J(\theta) = \frac{1}{m} \sum_{i=1}^{m} \mathcal{L}(h_\theta(x^{(i)}), y^{(i)}) + \lambda_1 \sum_{j=1}^{n} |\theta_j| + \lambda_2 \sum_{j=1}^{n} \theta_j^2
#    \]
#
#    where \( \lambda_1 \) and \( \lambda_2 \) are the regularization parameters for L1 and L2, respectively.
#
# 3. **Use libraries**: Scikit-learn also supports Elastic Net regularization.
#
#    ```python
#    from sklearn.linear_model import ElasticNet
#
#    # Instantiate an ElasticNet regressor with regularization parameters alpha and l1_ratio
#    elastic_net = ElasticNet(alpha=1.0, l1_ratio=0.5)
#    elastic_net.fit(X_train, y_train)
#
#    # Predict
#    y_pred = elastic_net.predict(X_test)
#    ```
#
# ### General Tips
#
# - **Choose the right regularization strength**: The parameter \( \lambda \) (or `alpha` in Scikit-learn) controls the regularization strength. Use techniques like cross-validation to select the best value.
# - **Feature scaling**: Regularization works better when features are on a similar scale. Ensure your features are standardized or normalized.
# - **Interpret results**: L1 regularization can set some coefficients to zero, making the model easier to interpret. L2 regularization tends to spread the error across all weights but doesn’t eliminate features entirely.
# - **Combining regularizations**: Elastic Net is particularly useful when you have many features and you expect some of them to be irrelevant.
#
# By carefully applying these regularization methods, you can build more robust models that generalize better to new data.

# %% [markdown]
# Using unsupervised learning to pre-train a model before fine-tuning it with labeled data is indeed related to a technique called semi-supervised learning. Semi-supervised learning leverages both labeled and unlabeled data for training, typically using the abundant unlabeled data to improve the model's performance. Here's a detailed guide on how to do this:
#
# ### Steps to Use Unsupervised Learning for Pre-Training
#
# 1. **Collect and preprocess your data**:
#    - Separate your data into labeled and unlabeled datasets.
#    - Ensure the data is preprocessed (normalized/scaled, missing values handled, etc.)
#
# 2. **Unsupervised pre-training**:
#    - Choose an unsupervised learning algorithm suitable for your data. Common choices include autoencoders, clustering algorithms like k-means, or dimensionality reduction techniques like PCA (Principal Component Analysis).
#    - Train the unsupervised model on the unlabeled data.
#
# 3. **Extract features or initialize the model**:
#    - Use the trained unsupervised model to extract features from both labeled and unlabeled data. For example, you can use the encoder part of an autoencoder to obtain a compressed representation of the data.
#    - Alternatively, use the weights/parameters learned during the unsupervised phase to initialize your supervised model.
#
# 4. **Fine-tune with labeled data**:
#    - Initialize a supervised learning model with the features or parameters obtained from the unsupervised learning step.
#    - Train the supervised model on the labeled dataset.
#
# ### Example using an Autoencoder (Deep Learning Approach)
#
# Here’s an example using a deep learning approach with an autoencoder for pre-training, followed by fine-tuning with labeled data.
#
# #### Step 1: Pre-training with an Autoencoder
#
# 1. **Define the autoencoder**:
#    ```python
#    from tensorflow.keras.layers import Input, Dense
#    from tensorflow.keras.models import Model
#
#    input_dim = X_unlabeled.shape[1]
#
#    # Define encoder
#    input_layer = Input(shape=(input_dim,))
#    encoded = Dense(64, activation='relu')(input_layer)
#    encoded = Dense(32, activation='relu')(encoded)
#
#    # Define decoder
#    decoded = Dense(64, activation='relu')(encoded)
#    decoded = Dense(input_dim, activation='sigmoid')(decoded)
#
#    # Autoencoder model
#    autoencoder = Model(input_layer, decoded)
#    autoencoder.compile(optimizer='adam', loss='mse')
#
#    # Train autoencoder
#    autoencoder.fit(X_unlabeled, X_unlabeled, epochs=50, batch_size=256, shuffle=True)
#    ```
#
# 2. **Extract features using the encoder**:
#    ```python
#    encoder = Model(input_layer, encoded)
#    X_unlabeled_encoded = encoder.predict(X_unlabeled)
#    X_labeled_encoded = encoder.predict(X_labeled)
#    ```
#
# #### Step 2: Fine-tuning with Labeled Data
#
# 1. **Define and initialize the supervised model**:
#    ```python
#    from tensorflow.keras.layers import Input, Dense
#    from tensorflow.keras.models import Model
#
#    # Define the supervised model
#    input_layer = Input(shape=(32,))  # Use encoded feature size
#    dense_layer = Dense(64, activation='relu')(input_layer)
#    output_layer = Dense(1, activation='sigmoid')(dense_layer)  # Adjust for your problem
#
#    supervised_model = Model(input_layer, output_layer)
#    supervised_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#
#    # Train the supervised model on the encoded labeled data
#    supervised_model.fit(X_labeled_encoded, y_labeled, epochs=50, batch_size=32, shuffle=True)
#    ```
#
# ### Semi-Supervised Learning
#
# Semi-supervised learning refers to methods that make use of both labeled and unlabeled data. The process described above is one approach to semi-supervised learning. Other common techniques include:
#
# 1. **Self-training**: The model is initially trained on labeled data. It then makes predictions on the unlabeled data, and the most confident predictions are added to the labeled dataset for further training.
#
# 2. **Co-training**: Two or more models are trained on different views of the data. Each model is used to label the unlabeled data for the other model.
#
# 3. **Consistency regularization**: The model is trained to be invariant to data augmentations or perturbations on the unlabeled data.
#
# By using these approaches, semi-supervised learning can significantly enhance the performance of models, especially when labeled data is scarce but unlabeled data is plentiful.

# %%
# import the necessaries package
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_validate, KFold
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score, r2_score, f1_score, recall_score, precision_score, confusion_matrix, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from imblearn.pipeline import make_pipeline

import warnings
warnings.filterwarnings("ignore")
random_state= 42

# %%
# import the dataset
df_mat = pd.read_csv("student-mat.csv", sep=";")
df_por = pd.read_csv("student-por.csv", sep=";")

# %%
# append the data together 
full_df=pd.concat([df_mat,df_por],axis=0)

# %%
# Change categorical columns to datatype "category"

for col in['school', 'sex', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health']:
    full_df[col] = full_df[col].astype('category')

# %%
# find the average score of the three term then regards it as final score
full_df["Average Score"]= round(full_df[["G1", "G2", "G3"]].mean(axis=1),1)
full_df.drop(columns=["G1", "G2", "G3"], inplace=True)

# %% [markdown]
# # Data Accessing

# %%
# check the summary of the data
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1044 entries, 0 to 648
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   school         1044 non-null   category
#  1   sex            1044 non-null   category
#  2   age            1044 non-null   int64
#  3   address        1044 non-null   category
#  4   famsize        1044 non-null   category
#  5   Pstatus        1044 non-null   category
#  6   Medu           1044 non-null   category
#  7   Fedu           1044 non-null   category
#  8   Mjob           1044 non-null   category
#  9   Fjob           1044 non-null   category
#  10  reason         1044 non-null   category
#  11  guardian       1044 non-null   category
#  12  traveltime     1044 non-null   category
#  13  studytime      1044 non-null   category
#  14  failures       1044 non-null   category
#  15  schoolsup      1044 non-null   category
#  16  famsup         1044 non-null   category
# ...

# %%
# check the dimension of the dataset
full_df.shape
# Out:
# (1044, 31)

# %%
# check for duplicates entries
full_df.duplicated().sum()
# Out:
# 2

# %%
for i in full_df.select_dtypes("category").columns:
    sns.countplot(x=full_df[i])
    plt.title(f"Count of {i}")
    plt.show()

# %%
for i in full_df.select_dtypes(["int64", "float64"]).columns:
    sns.distplot(x=full_df[i])
    plt.title(f"{i} Distribution")
    plt.show()

# %% [markdown]
# # Univariate Analysis

# %%
def bar_plot_for_bivariate(col):
    average_score=full_df.groupby(col).agg({"Average Score":"mean"})
    sns.barplot(x=average_score.index, y=average_score.values.flatten())
    plt.title(f"Average Score across {col}")
    plt.ylabel("Average")
    plt.show()

# %%
bar_plot_for_bivariate("school")

# %%
bar_plot_for_bivariate("sex")

# %%
nib= [0, 9.5, 11.5,  13.5,  15.5, 20]
levels = ['fail', 'fair', 'satisfactory', 'good', 'excellent']
full_df["exam remark"]=pd.cut(full_df["Average Score"], bins=nib, labels=levels)

# %%
X = full_df.drop(columns=[ 'Average Score', 'exam remark'])

y = full_df["exam remark"]
encoder={"fail":0, "fair":1, "satisfactory":2, "good":3, "excellent":4}
y = y.map(encoder)

# %%
nominal_columns =X[["school", "sex", "address", 'Pstatus','reason', 'guardian',"failures" ,
                  'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 
                  'romantic']].columns
numerical_columns =X[["age", "absences"]].columns

ordinal_columns =X[["famsize", 
                          'Fedu','Mjob', "Fjob", "traveltime",
                          'traveltime', 'studytime', "famrel",
 'freetime', 'goout', 'Dalc','Walc', 'health']].columns

# %%
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.05, random_state=random_state)

# %%
##### from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# Create a pipeline with SMOTE for oversampling and RandomUnderSampler for undersampling
pipeline = make_pipeline(
    SMOTE(sampling_strategy='auto', random_state=42),
    RandomUnderSampler(sampling_strategy='auto', random_state=42)
    # You can add more steps if needed
)

# Apply the pipeline to the dataset
X_resampled, y_resampled = pipeline.fit_resample(X, y)
print(Counter(y_resampled))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from imblearn.over_sampling import SMOTE

# Replace these with your actual column names and data
numerical_features = list(X.select_dtypes("int").columns)
categorical_features = list(X.select_dtypes("category").columns)

# Create transformers for numerical and categorical features
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Create a column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Create a pipeline with preprocessing, oversampling, and any other steps
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('oversample', SMOTE(sampling_strategy='auto', random_state=42)),
    # Add more steps if needed
])

# Apply the pipeline to the dataset
X_resampled, y_resampled = pipeline.fit(X, y)

# %%
from imblearn.over_sampling import SMOTE
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import (
   # LogisticRegression,
   # DecisionTreeClassifier,
    RandomForestClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier,
)
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# Replace these with your actual classifiers
classifiers = [
    LogisticRegression(),
    DecisionTreeClassifier(),
    SVC(),
    RandomForestClassifier(),
    AdaBoostClassifier(),
    GradientBoostingClassifier(),
    GaussianNB(),
]

classifiers_names = [
    'Logistic Regression',
    'Decision Tree Classifier',
    'Support Vector Machine',
    'Random Forest Classifier',
    'AdaBoost Classifier',
    'Gradient Boosting Classifier',
    'Gaussian Naive Bayes',
]

# Assuming you have a transformer pipeline named transformer_pipeline
# Replace these with your actual feature names and data
numerical_features = list(X.select_dtypes("int").columns)
categorical_features = list(X.select_dtypes("category").columns)

# Create transformers for numerical and categorical features
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Create a column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Create a transformer pipeline
transformer_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    # Add more transformer steps if needed
])

# Create a pipeline with oversampling, preprocessing, and classifier
pipelines = [
    Pipeline([
        ('oversample', SMOTE(sampling_strategy='auto', random_state=42)),
        ('transformer', transformer_pipeline),
        (classifier_name, classifier)
    ])
    for classifier_name, classifier in zip(classifiers_names, classifiers)
]

# Now you have a list of pipelines, each including oversampling, preprocessing, and a classifier

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import SelectKBest, f_classif

# Extend the transformer pipeline with additional preprocessing steps
transformer_pipeline_extended = Pipeline([
    ('preprocessor', preprocessor),
    ('feature_selection', SelectKBest(score_func=f_classif, k=10)),  # Example: Select top 10 features
    ('polynomial_features', PolynomialFeatures(degree=2)),  # Example: Add polynomial features
    # Add more transformer steps as needed
])

# Modify the classifier pipelines to use the extended transformer pipeline
pipelines_extended = [
    Pipeline([
        ('oversample', SMOTE(sampling_strategy='auto', random_state=42)),
        ('transformer', transformer_pipeline_extended),
        (classifier_name, classifier)
    ])
    for classifier_name, classifier in zip(classifiers_names, classifiers)
]

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.decomposition import PCA
from sklearn.ensemble import IsolationForest

# Extend the transformer pipeline with additional preprocessing steps
transformer_pipeline_extended = Pipeline([
    ('preprocessor', preprocessor),
    ('feature_selection', SelectKBest(score_func=f_classif, k=10)),  # Example: Select top 10 features
    ('dimensionality_reduction', PCA(n_components=10)),  # Example: Reduce to 10 principal components
    ('outlier_handling', IsolationForest(contamination=0.05)),  # Example: Isolation Forest for outlier detection
    ('polynomial_features', PolynomialFeatures(degree=2)),  # Example: Add polynomial features
    # Add more transformer steps as needed
])

# Modify the classifier pipelines to use the extended transformer pipeline
pipelines_extended = [
    Pipeline([
        ('oversample', SMOTE(sampling_strategy='auto', random_state=42)),
        ('transformer', transformer_pipeline_extended),
        (classifier_name, classifier)
    ])
    for classifier_name, classifier in zip(classifiers_names, classifiers)
]

# %%
import pandas as pd
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import make_pipeline
from collections import Counter

# Create a custom transformer to convert the result to a DataFrame
class DataFrameConverter:
    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        return pd.DataFrame(X, columns=X.columns)

# Create a pipeline with SMOTE for oversampling, RandomUnderSampler for undersampling, and DataFrame conversion
pipeline = make_pipeline(
    SMOTE(sampling_strategy='auto', random_state=42),
    RandomUnderSampler(sampling_strategy='auto', random_state=42),
    DataFrameConverter()
    # You can add more steps if needed
)

# Apply the pipeline to the dataset
X_resampled = pipeline.fit_transform(X, y)
print(Counter(y_resampled))

# %%
# Out:
# ['age', 'absences']

# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# Create a custom transformer to convert the result to a DataFrame with column names
class DataFrameConverter:
    def __init__(self, column_names):
        self.column_names = column_names

    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        return pd.DataFrame(X, columns=self.column_names)

# Assuming X is a pandas DataFrame and y is a pandas Series or numpy array
XX = X.select_dtypes("int")  # Assuming 'X' contains numerical data
yy = y  # Target variable (assumed to be in a pandas Series or numpy array)

# Define column names based on the selected data types
column_names = list(XX.columns)

# Initialize the resampling objects
smote = SMOTE(sampling_strategy='auto', random_state=42)
undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)

# Apply SMOTE for oversampling, then RandomUnderSampler for undersampling
X_resampled, y_resampled = smote.fit_resample(XX, yy)
X_resampled, y_resampled = undersampler.fit_resample(X_resampled, y_resampled)

# Convert the resampled data back to a DataFrame using the custom transformer
df_converter = DataFrameConverter(column_names)
X_resampled_df = df_converter.transform(X_resampled)

# Print the class distribution of the resampled labels
print(Counter(y_resampled))
# Out:
# Counter({0: 284, 1: 284, 2: 284, 3: 284, 4: 284})

# %%
pd.DataFrame(X_resampled)
# Out:
#       age  absences
# 0      18         6
# 1      17         4
# 2      15        10
# 4      16         4
# 7      17         6
# ...   ...       ...
# 1374   16         2
# 1349   18         2
# 1256   18         0
# 580    16         0
# 1384   16         2
#
# [1420 rows x 2 columns]

# %%
transformer = [
    ("ordinal variable", OrdinalEncoder(), ordinal_columns),
    ("nominal variable", OneHotEncoder(drop="first", sparse_output=False), nominal_columns),
    ("numerical variable", StandardScaler(), numerical_columns)
]
proccessor = ColumnTransformer(transformer, remainder="passthrough")

# %%
classifiers=[GaussianNB(), RandomForestClassifier(), AdaBoostClassifier(), GradientBoostingClassifier(),
DecisionTreeClassifier(), LogisticRegression(), SVC()]

classifier_names = ["GaussianNB", "RandomForestClassifier", "AdaBoostClassifier", "GradientBoostingClassifier",
"DecisionTreeClassifier", "LogisticRegression", "SVC"]

# %%
model_pipeline = [    Pipeline( [("processor", proccessor), (classifier_name, classifier) ])
                  for classifier_name, classifier in zip(classifier_names, classifiers)
                 ]

# %%
cv=KFold(5)
scoring = {"acc":"accuracy"}

# %%
training_scores = []
cv_scores = {classifier_name:[] for classifier_name in classifier_names}
for classifier_name, pipeline in zip(classifier_names, model_pipeline):
    cv_score = cross_validate(estimator=pipeline, X=x_train, y=y_train, cv=cv, scoring=scoring,
                             return_estimator=True, return_train_score=True)
    training_score = cv_score["train_acc"]
    training_score = np.mean(training_score) * 100
    training_scores.append(training_score)
    cv_scores[classifier_name].append(cv_score)

# %%
best_estimators = {classifier_name:[] for classifier_name in classifier_names}
for model_name, estimator in cv_scores.items():
    best_test_score_indx=np.argmax(estimator[0]["test_acc"])
    best_estimator=estimator[0]["estimator"][best_test_score_indx]
    best_estimators[model_name].append(best_estimator)

# %%
model_test_scores, precisions, accuracys, recalls, r2s, f1s =[], [], [], [], [], []
for  model_name, estimator in best_estimators.items():
    estimators=estimator[0]
    y_pred = estimators.predict(x_val)
    model_test_score=estimators.score(x_val, y_val)
    precision = precision_score(y_val, y_pred, average="weighted")
    accuracy = accuracy_score(y_val, y_pred)
    recall = recall_score(y_val, y_pred ,average="weighted")  
    r2 = r2_score(y_val, y_pred) 
    r1 = f1_score(y_val, y_pred, average="weighted") 
    
    model_test_scores.append(model_test_score)
    precisions.append(precision)    
    accuracys.append(accuracy)    
    recalls.append(recall)    
    r2s.append(r2)    
    f1s.append(r1)

# %%
result_df =pd.DataFrame({
    "Model": classifier_names,
    "training_score": np.array(training_scores),
    "testing_score": np.array(model_test_scores) * 100,
    "precisions_score": np.array(precisions) * 100,
    "recalls_score": np.array(recalls) * 100,
    "r2s_score": np.array(r2s) ,
    "f1s_score": np.array(f1s) 
})
result_df
# Out:
#                         Model  training_score  testing_score  \
# 0                  GaussianNB       20.836932      30.188679
# 1      RandomForestClassifier       98.259200      22.641509
# 2          AdaBoostClassifier       40.741049      28.301887
# 3  GradientBoostingClassifier       80.373215      18.867925
# 4      DecisionTreeClassifier       98.259200      28.301887
# 5          LogisticRegression       45.105914      26.415094
# 6                         SVC       45.357739      16.981132
#
#    precisions_score  recalls_score  r2s_score  f1s_score
# 0         20.441907      30.188679  -1.330746   0.205916
# 1         36.485849      22.641509  -0.155580   0.233304
# 2         39.953755      28.301887  -0.380820   0.313361
# 3         35.160228      18.867925  -0.214339   0.208416
# 4         32.274457      28.301887  -0.488544   0.298309
# 5         32.719377      26.415094  -0.243718   0.257404
# 6         18.599104      16.981132  -0.537509   0.156784

# %%
best_estimators["GaussianNB"][0].predict(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 best_estimators["GaussianNB"][0].predict(c)
#
# NameError: name 'c' is not defined

# %%
c=X.iloc[:1,:]

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(15, 15))
ax[0].set_xlim(0, 100)
ax[1].set_xlim(0, 100)

sns.barplot(data=result_df, y= "Model", x="training_score", ax=ax[0],
            order=result_df.sort_values(by="training_score", ascending=False).Model)

sns.barplot(data=result_df, y= "Model", x="testing_score", ax=ax[1],
            order=result_df.sort_values(by="testing_score", ascending=False).Model)
plt.show()
